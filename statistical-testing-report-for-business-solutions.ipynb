# %% [markdown]
# I. Project description: Statistical testing report for Automatidata to study if customers who use a credit card pay higher fare amounts than those who use cash?
#
#
# Aim of project: To conduct statistical testing on the data to understand how variables involved are related.
#
# Client: Automatidata
#
# Links: [github link](https://github.com/aniekanekanem/Automatidata-project/blob/main/Activity_%20Course%204%20Automatidata%20project%20lab.ipynb) for business solution using statistical testing study and observation for Automatidata
#
#
#
# II. Project description: Statistical testing report for TikTok to investigate the claims classification data such as the relationship between the video view counts and the author's verification status.
#
# Aim of project: To conduct statistical testing on the data to investigate the relationship between the video view counts and the author’s verification status.
#
#
# Client: TikTok
#
# Links: [github link](https://github.com/aniekanekanem/TikTok-Project/blob/main/Activity_Course%204%20TikTok%20project%20lab.ipynb) for business solution using statistical testing  study and observation for TikTok
#
#
# III. Project description: Statistical testing report for Waze to help prevent user churn on the app.
#
# Aim of project: To prevent user churn on the Waze app.
#
# Client: Waze
#
# Links: [github link](https://github.com/aniekanekanem/Waze-project/blob/main/Activity_Course%204%20Waze%20project%20lab.ipynb) for business solution using statistical testing  study and observation for Waze
